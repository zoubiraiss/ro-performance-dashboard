# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Lenovo\Desktop\transction from chemstry to ai powrd data scinces\project1\.venv\Scripts\python.exe

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
print("Import successful")
# Out:
# Import successful
